# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("train.csv")

# %%
print(data)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
print(data.dropna())
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
print(data.describe())
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
print(np.mean(data['Sales']))
# Out:
# 230.76905945918367

# %%
print(data.groupby('Product Name')['Sales'].sum())
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                     25.228
# #10 Gummed Flap White Envelopes, 100/Box                                                                 41.300
# #10 Self-Seal White Envelopes                                                                           108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                              379.214
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                 286.672
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4     477.660
# iOttie HLCRIO102 Car Mount                                                                              215.892
# ...

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x, y)
plt.title("Line Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("train.csv")

# %%
data.groupby('State')['Sales'].sum().plot(kind='bar')
plt.title("Sales by State")
plt.show()

# %%
data['Sales'].plot(kind='hist')
plt.title("Sales Distribution")
plt.show()

# %%
data.groupby('Country')['Sales'].sum().plot(kind='bar')
plt.title("Sales by City")
plt.show()

# %%
plt.scatter(data['Sales'], data['State'])
plt.title("Sales vs State")
plt.xlabel("Sales")
plt.ylabel("State")
plt.show()

# %%
top_states = data.groupby('State')['Sales'].sum().nlargest(5).index

filtered_data = data[data['State'].isin(top_states)]

plt.scatter(filtered_data['Sales'], filtered_data['State'])
plt.title("Top 5 States by Sales")
plt.xlabel("Sales")
plt.ylabel("State")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x=data['Sales'])
plt.show()

# %%
sns.histplot(data['Sales'])
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px
data = pd.read_csv("train.csv")

# %%
fig = px.bar(data, x='Category', y='Sales')
fig.show()

# %%
fig = px.bar(data, x='Category', y='Sales', color='Category')
fig.show()

# %%
fig = px.pie(data, names='Category', values='Sales')
fig.show()

# %%
fig = px.line(data, x='Order Date', y='Sales')
fig.show()

# %%
fig = px.scatter(data, x='Sales', y='Row ID', color='Category')
fig.show()

# %%
fig = px.bar(data, x='Category', y='Sales', color='Region')
fig.show()

# %%
grouped = data.groupby('Category')['Sales'].sum().reset_index()

fig = px.bar(grouped, x='Category', y='Sales')
fig.show()

# %%
import streamlit as st

# %%
st.title("📊 Sales Dashboard")
# Out:
# 2026-04-16 22:39:55.783 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:39:56.304
# ...
#   command:
#
#     streamlit run C:\Users\ansar\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-16 22:39:56.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:39:56.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
data = pd.read_csv("train.csv")

# %%
fig = px.bar(data, x='Category', y='Sales', color='Category')
st.plotly_chart(fig)
# Out:
# 2026-04-16 22:40:55.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:40:55.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:40:55.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:40:55.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:40:55.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.write("Dataset Preview")
st.dataframe(data.head())
# Out:
# 2026-04-16 22:41:14.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:14.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:14.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:15.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:15.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:15.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
fig2 = px.pie(data, names='Region', values='Sales')
st.plotly_chart(fig2)
# Out:
# 2026-04-16 22:41:40.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:40.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:40.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:40.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 22:41:40.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("train.csv")

# %%
print(data.tail())
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...
