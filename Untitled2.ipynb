# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data.xlsx")

# %%
print(data.head())
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000

# %%
print(data.columns)
# Out:
# Index(['Product', 'City', 'Sales'], dtype='object')

# %%
filtered = data[data['City'] == 'Mumbai']

# %%
print(filtered)
# Out:
#   Product    City  Sales
# 1  Mobile  Mumbai  30000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000

# %%
print(data.tail())
# Out:
#   Product    City  Sales
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000

# %%
print(data.head())
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  9 non-null      object
#  1   City     9 non-null      object
#  2   Sales    9 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 348.0+ bytes
# None

# %%
print(data.describe())
# Out:
#               Sales
# count      9.000000
# mean   41222.222222
# std    25655.300514
# min    20000.000000
# 25%    22000.000000
# 50%    28000.000000
# 75%    70000.000000
# max    80000.000000

# %%
data['Sales']
# Out:
# 0    75000
# 1    30000
# 2    20000
# 3    80000
# 4    25000
# 5    22000
# 6    70000
# 7    28000
# 8    21000
# Name: Sales, dtype: int64

# %%
pune_data = data[data['City'] == 'Pune']

# %%
print(pune_data)
# Out:
#   Product  City  Sales
# 0  Laptop  Pune  75000
# 2  Tablet  Pune  20000
# 4  Mobile  Pune  25000

# %%
data[(data['City'] == 'Pune') & (data['Sales'] > 1000)]
# Out:
#   Product  City  Sales
# 0  Laptop  Pune  75000
# 2  Tablet  Pune  20000
# 4  Mobile  Pune  25000

# %%
data.sort_values(by='Sales', ascending=False)
# Out:
#   Product    City  Sales
# 3  Laptop   Delhi  80000
# 0  Laptop    Pune  75000
# 6  Laptop  Mumbai  70000
# 1  Mobile  Mumbai  30000
# 7  Mobile   Delhi  28000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 8  Tablet   Delhi  21000
# 2  Tablet    Pune  20000

# %%
data.isnull()
# Out:
#    Product   City  Sales
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# 5    False  False  False
# 6    False  False  False
# 7    False  False  False
# 8    False  False  False

# %%
result = data.groupby('Product')['Sales'].sum()

# %%
result.plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
data['Sales'].plot()
plt.show()

# %%
data.pivot_table(values='Sales', index='Product', aggfunc='sum')
# Out:
#           Sales
# Product
# Laptop   225000
# Mobile    83000
# Tablet    63000

# %%
data.pivot_table(values='Sales', index='City', aggfunc='sum')
# Out:
#          Sales
# City
# Delhi   129000
# Mumbai  122000
# Pune    120000

# %%
data.pivot_table(values='Sales', index=['City', 'Product'], aggfunc='sum')
# Out:
#                 Sales
# City   Product
# Delhi  Laptop   80000
#        Mobile   28000
#        Tablet   21000
# Mumbai Laptop   70000
#        Mobile   30000
#        Tablet   22000
# Pune   Laptop   75000
#        Mobile   25000
#        Tablet   20000

# %%
print(data)
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000

# %%
data.pivot_table(values='Sales', index='City', aggfunc='mean')
# Out:
#                Sales
# City
# Delhi   43000.000000
# Mumbai  40666.666667
# Pune    40000.000000

# %%
data.drop_duplicates()
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000
