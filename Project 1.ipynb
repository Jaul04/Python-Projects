# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("data.xlsx")
print(data.head())
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000

# %%
print(data.columns)
# Out:
# Index(['Product', 'City', 'Sales'], dtype='object')

# %%
filtered = data[data['City'] == 'Pune']

# %%
print(filtered)
# Out:
#   Product  City  Sales
# 0  Laptop  Pune  75000
# 2  Tablet  Pune  20000
# 4  Mobile  Pune  25000

# %%
filtered = data[(data['City'] == 'Pune') & (data['Sales'] > 500)]

# %%
print(filtered)
# Out:
#   Product  City  Sales
# 0  Laptop  Pune  75000
# 2  Tablet  Pune  20000
# 4  Mobile  Pune  25000

# %%
result = data.groupby('Product')['Sales'].sum()

# %%
print(result)
# Out:
# Product
# Laptop    225000
# Mobile     83000
# Tablet     63000
# Name: Sales, dtype: int64

# %%
result = data.groupby('City')['Sales'].mean()

# %%
print(result)
# Out:
# City
# Delhi     43000.000000
# Mumbai    40666.666667
# Pune      40000.000000
# Name: Sales, dtype: float64

# %%
result = data.groupby(['Product','City'])['Sales'].sum()

# %%
print(result)
# Out:
# Product  City
# Laptop   Delhi     80000
#          Mumbai    70000
#          Pune      75000
# Mobile   Delhi     28000
#          Mumbai    30000
#          Pune      25000
# Tablet   Delhi     21000
#          Mumbai    22000
#          Pune      20000
# Name: Sales, dtype: int64

# %%
sorted_data = data.sort_values(by='Sales', ascending=False)

# %%
print(sorted_data)
# Out:
#   Product    City  Sales
# 3  Laptop   Delhi  80000
# 0  Laptop    Pune  75000
# 6  Laptop  Mumbai  70000
# 1  Mobile  Mumbai  30000
# 7  Mobile   Delhi  28000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 8  Tablet   Delhi  21000
# 2  Tablet    Pune  20000

# %%
print(data.isnull().sum())
# Out:
# Product    0
# City       0
# Sales      0
# dtype: int64

# %%
data['Profit'] = data['Sales'] * 0.5
print(data.head())
# Out:
#   Product    City  Sales   Profit
# 0  Laptop    Pune  75000  37500.0
# 1  Mobile  Mumbai  30000  15000.0
# 2  Tablet    Pune  20000  10000.0
# 3  Laptop   Delhi  80000  40000.0
# 4  Mobile    Pune  25000  12500.0

# %%
import matplotlib.pyplot as plt

# %%
result = data.groupby('Product')['Sales'].sum()

# %%
result.plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
plt.show()

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  9 non-null      object
#  1   City     9 non-null      object
#  2   Sales    9 non-null      int64
#  3   Profit   9 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 420.0+ bytes
# None

# %%
print(data.describe())
# Out:
#               Sales        Profit
# count      9.000000      9.000000
# mean   41222.222222  20611.111111
# std    25655.300514  12827.650257
# min    20000.000000  10000.000000
# 25%    22000.000000  11000.000000
# 50%    28000.000000  14000.000000
# 75%    70000.000000  35000.000000
# max    80000.000000  40000.000000

# %%
data = data.dropna()

# %%
data
# Out:
#   Product    City  Sales   Profit
# 0  Laptop    Pune  75000  37500.0
# 1  Mobile  Mumbai  30000  15000.0
# 2  Tablet    Pune  20000  10000.0
# 3  Laptop   Delhi  80000  40000.0
# 4  Mobile    Pune  25000  12500.0
# 5  Tablet  Mumbai  22000  11000.0
# 6  Laptop  Mumbai  70000  35000.0
# 7  Mobile   Delhi  28000  14000.0
# 8  Tablet   Delhi  21000  10500.0

# %%
data['Sales'] = data['Sales'].astype(int)

# %%
data
# Out:
#   Product    City  Sales   Profit
# 0  Laptop    Pune  75000  37500.0
# 1  Mobile  Mumbai  30000  15000.0
# 2  Tablet    Pune  20000  10000.0
# 3  Laptop   Delhi  80000  40000.0
# 4  Mobile    Pune  25000  12500.0
# 5  Tablet  Mumbai  22000  11000.0
# 6  Laptop  Mumbai  70000  35000.0
# 7  Mobile   Delhi  28000  14000.0
# 8  Tablet   Delhi  21000  10500.0

# %%
pune_data = data[data['City'] == 'Pune']
print(pune_data)
# Out:
#   Product  City  Sales   Profit
# 0  Laptop  Pune  75000  37500.0
# 2  Tablet  Pune  20000  10000.0
# 4  Mobile  Pune  25000  12500.0

# %%
result.plot(kind='pie')
plt.show()

# %%
city_sales = data.groupby('City')['Sales'].sum()

# %%
print(city_sales)
# Out:
# City
# Delhi     129000
# Mumbai    122000
# Pune      120000
# Name: Sales, dtype: int64

# %%
product_sales = data.groupby('Product')['Sales'].sum()

# %%
print(product_sales)
# Out:
# Product
# Laptop    225000
# Mobile     83000
# Tablet     63000
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(10,5))

# %%
plt.subplot(1,1,1)
product_sales.plot(kind='bar')
plt.title("Product Sales")
# Out:
# Text(0.5, 1.0, 'Product Sales')

# %%
plt.subplot(1,3,2)
city_sales.plot(kind='pie')
plt.title("City Sales")
# Out:
# Text(0.5, 1.0, 'City Sales')

# %%
plt.subplot(1,3,3)
data['Sales'].plot()
plt.title("Sales Trend")
# Out:
# Text(0.5, 1.0, 'Sales Trend')

# %%
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data.xlsx")
print(data.head())
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000

# %%
print(data)
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000

# %%
import matplotlib.pyplot as plt

x = ['A', 'B', 'C', 'D']
y = [5, 7, 3, 8]

plt.bar(x, y)
plt.title("Bar Graph")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 13, 17]

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
