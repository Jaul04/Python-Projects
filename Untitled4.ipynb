# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("data.xlsx")

# %%
print(data)
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000

# %%
print(data.head())
# Out:
#   Product    City  Sales
# 0  Laptop    Pune  75000
# 1  Mobile  Mumbai  30000
# 2  Tablet    Pune  20000
# 3  Laptop   Delhi  80000
# 4  Mobile    Pune  25000

# %%
print(data.tail())
# Out:
#   Product    City  Sales
# 4  Mobile    Pune  25000
# 5  Tablet  Mumbai  22000
# 6  Laptop  Mumbai  70000
# 7  Mobile   Delhi  28000
# 8  Tablet   Delhi  21000

# %%
print(data.describe())
# Out:
#               Sales
# count      9.000000
# mean   41222.222222
# std    25655.300514
# min    20000.000000
# 25%    22000.000000
# 50%    28000.000000
# 75%    70000.000000
# max    80000.000000

# %%
print(data.isnull().sum())
# Out:
# Product    0
# City       0
# Sales      0
# dtype: int64

# %%
data['Profit'] = data['Sales'] * 0.5
print(data.head())
# Out:
#   Product    City  Sales   Profit
# 0  Laptop    Pune  75000  37500.0
# 1  Mobile  Mumbai  30000  15000.0
# 2  Tablet    Pune  20000  10000.0
# 3  Laptop   Delhi  80000  40000.0
# 4  Mobile    Pune  25000  12500.0

# %%
result = data.groupby('Product')['Sales'].sum()

# %%
print(result)
# Out:
# Product
# Laptop    225000
# Mobile     83000
# Tablet     63000
# Name: Sales, dtype: int64

# %%
result.plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
8
