# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("assignment_data.xlsx")

# %%
print(data.head())
# Out:
#    OrderID Product     Category       City  Sales  Quantity
# 0        1  Laptop  Electronics      Delhi  87997         3
# 1        2  Tablet  Electronics  Bangalore  82654         5
# 2        3  Laptop  Electronics     Mumbai  69255         3
# 3        4  Camera  Electronics     Mumbai  72989         2
# 4        5  Laptop  Electronics     Mumbai  42248         2

# %%
print(data.tail())
# Out:
#     OrderID     Product     Category       City  Sales  Quantity
# 25       26      Laptop  Electronics     Mumbai  34402         5
# 26       27      Laptop  Electronics  Bangalore  23373         5
# 27       28      Mobile  Electronics      Delhi  82768         2
# 28       29      Mobile  Electronics       Pune  66328         1
# 29       30  Headphones  Accessories  Bangalore  17568         3

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   30 non-null     int64
#  1   Product   30 non-null     object
#  2   Category  30 non-null     object
#  3   City      30 non-null     object
#  4   Sales     30 non-null     int64
#  5   Quantity  30 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.5+ KB
# None

# %%
print(data.describe())
# Out:
#          OrderID         Sales   Quantity
# count  30.000000     30.000000  30.000000
# mean   15.500000  51506.733333   2.533333
# std     8.803408  23723.641943   1.357821
# min     1.000000  15010.000000   1.000000
# 25%     8.250000  27306.000000   1.250000
# 50%    15.500000  51120.500000   2.000000
# 75%    22.750000  69195.000000   3.000000
# max    30.000000  89402.000000   5.000000

# %%
print(data.isnull())
# Out:
#     OrderID  Product  Category   City  Sales  Quantity
# 0     False    False     False  False  False     False
# 1     False    False     False  False  False     False
# 2     False    False     False  False  False     False
# 3     False    False     False  False  False     False
# 4     False    False     False  False  False     False
# 5     False    False     False  False  False     False
# 6     False    False     False  False  False     False
# 7     False    False     False  False  False     False
# 8     False    False     False  False  False     False
# 9     False    False     False  False  False     False
# 10    False    False     False  False  False     False
# 11    False    False     False  False  False     False
# 12    False    False     False  False  False     False
# 13    False    False     False  False  False     False
# 14    False    False     False  False  False     False
# 15    False    False     False  False  False     False
# ...

# %%
print(data.isnull().sum())
# Out:
# OrderID     0
# Product     0
# Category    0
# City        0
# Sales       0
# Quantity    0
# dtype: int64

# %%
data = data.dropna()

# %%
Pune_data = data[data['City'] == 'Pune']

# %%
print(Pune_data)
# Out:
#     OrderID     Product     Category  City  Sales  Quantity
# 9        10  Headphones  Accessories  Pune  24592         4
# 10       11      Mobile  Electronics  Pune  42546         1
# 17       18      Camera  Electronics  Pune  25630         5
# 18       19      Laptop  Electronics  Pune  31428         2
# 19       20      Tablet  Electronics  Pune  21536         2
# 20       21      Camera  Electronics  Pune  69015         2
# 28       29      Mobile  Electronics  Pune  66328         1

# %%
Product_sale = data.groupby('Product')['Sales'].sum()

# %%
print(Product_sale)
# Out:
# Product
# Camera        272046
# Headphones    170333
# Laptop        582823
# Mobile        370042
# Tablet        149958
# Name: Sales, dtype: int64

# %%
City_Sale = data.groupby('City')['Sales'].sum()

# %%
print(City_Sale)
# Out:
# City
# Bangalore    393823
# Delhi        315695
# Mumbai       554609
# Pune         281075
# Name: Sales, dtype: int64

# %%
Top_Sale = data.sort_values(by='Sales', ascending=True)

# %%
print(Top_Sale)
# Out:
#     OrderID     Product     Category       City  Sales  Quantity
# 14       15      Camera  Electronics     Mumbai  89402         2
# 0         1      Laptop  Electronics      Delhi  87997         3
# 27       28      Mobile  Electronics      Delhi  82768         2
# 1         2      Tablet  Electronics  Bangalore  82654         5
# 15       16      Laptop  Electronics     Mumbai  81393         3
# 5         6      Mobile  Electronics      Delhi  74258         1
# 3         4      Camera  Electronics     Mumbai  72989         2
# 2         3      Laptop  Electronics     Mumbai  69255         3
# 20       21      Camera  Electronics       Pune  69015         2
# 23       24      Laptop  Electronics  Bangalore  68656         3
# 28       29      Mobile  Electronics       Pune  66328         1
# 6         7      Mobile  Electronics     Mumbai  65828         1
# 8         9      Laptop  Electronics  Bangalore  61800         1
# ...

# %%
print(Top_Sale.head())
# Out:
#     OrderID Product     Category       City  Sales  Quantity
# 14       15  Camera  Electronics     Mumbai  89402         2
# 0         1  Laptop  Electronics      Delhi  87997         3
# 27       28  Mobile  Electronics      Delhi  82768         2
# 1         2  Tablet  Electronics  Bangalore  82654         5
# 15       16  Laptop  Electronics     Mumbai  81393         3

# %%
data['Status'] = np.where(data['Sales'] > 50000, 'Good', 'Bad')

# %%
print(data.head())
# Out:
#    OrderID Product     Category       City  Sales  Quantity Status
# 0        1  Laptop  Electronics      Delhi  87997         3   Good
# 1        2  Tablet  Electronics  Bangalore  82654         5   Good
# 2        3  Laptop  Electronics     Mumbai  69255         3   Good
# 3        4  Camera  Electronics     Mumbai  72989         2   Good
# 4        5  Laptop  Electronics     Mumbai  42248         2    Bad

# %%
print(data)
# Out:
#     OrderID     Product     Category       City  Sales  Quantity Status
# 0         1      Laptop  Electronics      Delhi  87997         3   Good
# 1         2      Tablet  Electronics  Bangalore  82654         5   Good
# 2         3      Laptop  Electronics     Mumbai  69255         3   Good
# 3         4      Camera  Electronics     Mumbai  72989         2   Good
# 4         5      Laptop  Electronics     Mumbai  42248         2    Bad
# 5         6      Mobile  Electronics      Delhi  74258         1   Good
# 6         7      Mobile  Electronics     Mumbai  65828         1   Good
# 7         8      Laptop  Electronics      Delhi  21453         4    Bad
# 8         9      Laptop  Electronics  Bangalore  61800         1   Good
# 9        10  Headphones  Accessories       Pune  24592         4    Bad
# 10       11      Mobile  Electronics       Pune  42546         1    Bad
# 11       12      Camera  Electronics     Mumbai  15010         1    Bad
# ...

# %%
data['Discount'] = 5

# %%
print(data)
# Out:
#     OrderID     Product     Category       City  Sales  Quantity Status  \
# 0         1      Laptop  Electronics      Delhi  87997         3   Good
# 1         2      Tablet  Electronics  Bangalore  82654         5   Good
# 2         3      Laptop  Electronics     Mumbai  69255         3   Good
# 3         4      Camera  Electronics     Mumbai  72989         2   Good
# 4         5      Laptop  Electronics     Mumbai  42248         2    Bad
# 5         6      Mobile  Electronics      Delhi  74258         1   Good
# 6         7      Mobile  Electronics     Mumbai  65828         1   Good
# 7         8      Laptop  Electronics      Delhi  21453         4    Bad
# 8         9      Laptop  Electronics  Bangalore  61800         1   Good
# 9        10  Headphones  Accessories       Pune  24592         4    Bad
# 10       11      Mobile  Electronics       Pune  42546         1    Bad
# 11       12      Camera  Electronics     Mumbai  15010         1    Bad
# ...

# %%
data['Profit'] = data['Sales'] * 0.1

# %%
data['Total'] = data['Sales'] - data['Profit']

# %%
print(data)
# Out:
#     OrderID     Product     Category       City  Sales  Quantity Status  \
# 0         1      Laptop  Electronics      Delhi  87997         3   Good
# 1         2      Tablet  Electronics  Bangalore  82654         5   Good
# 2         3      Laptop  Electronics     Mumbai  69255         3   Good
# 3         4      Camera  Electronics     Mumbai  72989         2   Good
# 4         5      Laptop  Electronics     Mumbai  42248         2    Bad
# 5         6      Mobile  Electronics      Delhi  74258         1   Good
# 6         7      Mobile  Electronics     Mumbai  65828         1   Good
# 7         8      Laptop  Electronics      Delhi  21453         4    Bad
# 8         9      Laptop  Electronics  Bangalore  61800         1   Good
# 9        10  Headphones  Accessories       Pune  24592         4    Bad
# 10       11      Mobile  Electronics       Pune  42546         1    Bad
# 11       12      Camera  Electronics     Mumbai  15010         1    Bad
# ...

# %%
plt.figure(figsize=(10,5))

# %%
plt.subplot(1,1,1)
# Out:
# <Axes: >

# %%
Product_sale.plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
plt.title('Product Sale')
# Out:
# Text(0.5, 1.0, 'Product Sale')

# %%
plt.subplot(1,2,2)
City_Sale.plot(kind='pie')
plt.title("City Sales")
# Out:
# Text(0.5, 1.0, 'City Sales')

# %%
plt.subplot(1,1,1)
data['Sales'].plot()
plt.title("Sales Trend")
# Out:
# Text(0.5, 1.0, 'Sales Trend')

# %%
pune_data = data[data['City'] == 'Pune']
pune_sales = pune_data.groupby('Product')['Sales'].sum()

pune_sales.plot(kind='bar')
plt.show()

# %%
pivot = pd.pivot_table(data,
                       values='Sales',
                       index='City',
                       columns='Product',
                       aggfunc='sum')

print(pivot)
# Out:
# Product      Camera  Headphones    Laptop    Mobile   Tablet
# City
# Bangalore       NaN     96522.0  214647.0       NaN  82654.0
# Delhi           NaN     49219.0  109450.0  157026.0      NaN
# Mumbai     177401.0         NaN  227298.0  104142.0  45768.0
# Pune        94645.0     24592.0   31428.0  108874.0  21536.0

# %%
pivot = pd.pivot_table(data,
                       values='Sales',
                       index='City',
                       columns='Product',
                       aggfunc='sum',
                       fill_value=0)

print(pivot)
# Out:
# Product    Camera  Headphones  Laptop  Mobile  Tablet
# City
# Bangalore       0       96522  214647       0   82654
# Delhi           0       49219  109450  157026       0
# Mumbai     177401           0  227298  104142   45768
# Pune        94645       24592   31428  108874   21536

# %%
pivot = pd.pivot_table(data,
                       values=['Sales','Quantity'],
                       index='City',
                       columns='Product',
                       aggfunc='sum')

print(pivot)
# Out:
#           Quantity                                     Sales             \
# Product     Camera Headphones Laptop Mobile Tablet    Camera Headphones
# City
# Bangalore      NaN        7.0   10.0    NaN    5.0       NaN    96522.0
# Delhi          NaN        2.0    7.0    3.0    NaN       NaN    49219.0
# Mumbai         5.0        NaN   13.0    5.0    2.0  177401.0        NaN
# Pune           7.0        4.0    2.0    2.0    2.0   94645.0    24592.0
#
#
# Product      Laptop    Mobile   Tablet
# City
# Bangalore  214647.0       NaN  82654.0
# Delhi      109450.0  157026.0      NaN
# Mumbai     227298.0  104142.0  45768.0
# Pune        31428.0  108874.0  21536.0

# %%
pivot.plot(kind='bar')
plt.show()

# %%
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = data[['Quantity']]   # input
y = data['Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
print(predictions)
# Out:
# [49032.89962121 31698.25189394 43254.68371212 54811.1155303
#  49032.89962121 43254.68371212]

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test, y_test)
plt.plot(X_test, predictions)
plt.show()
